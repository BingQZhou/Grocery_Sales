# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# Import Statsmodels
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.vector_ar.vecm import coint_johansen
from statsmodels.stats.stattools import durbin_watson
from statsmodels.tsa.stattools import acf

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
def convert_date(str):
    """
    This method is used to convert a string into datetime.
    """
    arr = str.split("-")
    year = int(arr[0])
    month = int(arr[1])

    str = arr[2]
    arr = str.split()
    day = int(arr[0])
    date = datetime.datetime(year = year, month = month, day = day)
    return date

# %% [markdown]
# ## Get Data

# %%
data = pd.read_csv("data/train.csv")
test = pd.read_csv('data/test.csv')
display(data.head())
display(test.head())
# Out:
#                                  TICKET  UNITS      PRICE  REFERENCE  \
# 0  d9ea23a9-8a1b-41b4-b554-2bf7e96ca2d9  3.292   0.000000       1079
# 1  d9ea23a9-8a1b-41b4-b554-2bf7e96ca2d9  0.290   0.000000       2032
# 2  f4dd518d-1fd8-4339-abc6-2c5390c20e30 -1.000   0.000000       2032
# 3  aa299de6-1332-48ba-bce9-de8cbb48741e  3.292  10.909091       1001
# 4  aa299de6-1332-48ba-bce9-de8cbb48741e  1.000   0.000000       4019
#
#            CODE                         NAME  PRICEBUY  PRICESELL  \
# 0  1.079000e+03        Pumpkin Japanese/Kent       0.0       1.99
# 1  2.032000e+03                 Orange navel       0.0       2.99
# 2  2.032000e+03                 Orange navel       0.0       2.99
# 3  1.001000e+03   Australian Asparagus green       2.0       2.70
# 4  8.888101e+12            Nice Munchee 200g       0.9       1.50
#
#                DATENEW     PAYMENT   TOTAL TRANSID             CATERGORY
# 0  2016-03-16 23:15:39        cash   0.000   no ID              Pumpkins
# ...

# %% [markdown]
# ## Aggregation and Column Selection

# %%
def get_cate(df, category):
    '''
    get only rows with specific categories
    '''
    return df.loc[df['CATERGORY'] == category]

def select_cols(df):
    '''
    This method is used to select only the date and the units columns
    '''
    df = df[['DATENEW', 'UNITS']].copy()
    df['DATENEW'] = df['DATENEW'].apply(convert_date)
    df = df[["DATENEW", "UNITS"]].groupby('DATENEW').sum().reset_index()
    df = df.sort_values(by = "DATENEW", ascending = True)
    return df

def merge_dfs(base, df, index):
    '''
    This method is used to merge df to the base dataframe
    '''
    merged = base.merge(df, on = 'DATENEW', how = 'outer', suffixes = ('', '_' + str(index)))
    merged = merged.fillna(0)
    return merged

# %%
dict_of_cate = dict(zip(np.arange(0, 44), categories))
dict_of_cate
# Out:
# {0: 'Pumpkins',
#  1: 'Citrus',
#  2: 'Bunch Vegies',
#  3: 'Sri Lankan Groceries',
#  4: 'Other Vegies',
#  5: 'Veggies',
#  6: 'Cabbages',
#  7: 'Asian Vegies',
#  8: 'Stonefruits',
#  9: 'Onions',
#  10: 'carrots',
#  11: 'Tropical Fruits',
#  12: 'Melons',
#  13: 'Grapes',
#  14: 'Potatoes',
#  15: 'Tomatoes',
#  16: 'Cucumbers',
#  17: 'Bananas',
#  18: 'Apples',
#  19: 'Pears',
#  20: 'Chillies',
#  21: 'Other Fruits',
#  22: 'Nuts',
#  23: 'Herbs',
#  24: 'Mushrooms',
#  25: 'Lettuces',
#  26: 'capsicum',
#  27: 'Root Vegies',
#  28: 'Multi buy',
#  29: 'Eggs',
#  30: 'Avocadoes',
#  31: 'Berries',
#  32: 'Cut Veggies',
#  33: 'Flowers',
#  34: 'Olympian Products',
#  35: 'Groceries-Dry Goods',
#  36: 'Cut Fruits',
#  37: 'Kalamata olives',
#  38: 'coconut Products',
#  39: 'Fruits',
#  40: 'trutaste',
#  41: 'Pastas',
#  42: 'markdown bag'}

# %%
categories = data['CATERGORY'].unique()
categories
# Out:
# array(['Pumpkins', 'Citrus', 'Bunch Vegies', 'Sri Lankan Groceries',
#        'Other Vegies', 'Veggies', 'Cabbages', 'Asian Vegies',
#        'Stonefruits', 'Onions', 'carrots', 'Tropical Fruits', 'Melons',
#        'Grapes', 'Potatoes', 'Tomatoes', 'Cucumbers', 'Bananas', 'Apples',
#        'Pears', 'Chillies', 'Other Fruits', 'Nuts', 'Herbs', 'Mushrooms',
#        'Lettuces', 'capsicum', 'Root Vegies', 'Multi buy', 'Eggs',
#        'Avocadoes', 'Berries', 'Cut Veggies', 'Flowers',
#        'Olympian Products', 'Groceries-Dry Goods', 'Cut Fruits',
#        'Kalamata olives', 'coconut Products', 'Fruits', 'trutaste',
#        'Pastas', 'markdown bag'], dtype=object)

# %%
base = get_cate(data, 'Pumpkins')
base = select_cols(base)
index = 1
for cate in categories:
    if cate != 'Pumpkins':
        other = get_cate(data, cate)
        other = select_cols(other)
        base = merge_dfs(base, other, index)
        index += 1
merged = base
merged
# Out:
#         DATENEW   UNITS  UNITS_1  UNITS_2  UNITS_3  UNITS_4  UNITS_5  UNITS_6  \
# 0    2016-03-16   6.582   -0.420   10.020      1.0    1.290    1.000    0.000
# 1    2016-03-17  12.104   22.956    2.150      0.0   28.970    1.982    0.830
# 2    2016-03-18   8.496   13.878    3.000      2.0   11.420    1.098    1.000
# 3    2016-03-19   9.394   16.482    1.000      2.0   10.090    1.226    0.000
# 4    2016-03-20  13.858   15.444    5.000      1.0   18.648    0.000    2.000
# ...         ...     ...      ...      ...      ...      ...      ...      ...
# 998  2018-12-30   7.042   10.946   15.000     30.0   12.702    0.000    3.690
# 999  2018-12-31   6.772   13.998   29.352     19.0   25.314    0.000    3.078
# 1000 2016-03-28   0.000    2.684    6.000      2.0   11.822    0.000    1.000
# 1001 2017-01-02   0.000    6.948    8.000      1.0   15.234    0.000    0.000
# 1002 2018-10-07   0.000   21.882   18.000     20.0   42.564    0.000    1.000
#
# ...

# %%
#reset index
merged = merged.set_index('DATENEW')
merged
# Out:
#              UNITS  UNITS_1  UNITS_2  UNITS_3  UNITS_4  UNITS_5  UNITS_6  \
# DATENEW
# 2016-03-16   6.582   -0.420   10.020      1.0    1.290    1.000    0.000
# 2016-03-17  12.104   22.956    2.150      0.0   28.970    1.982    0.830
# 2016-03-18   8.496   13.878    3.000      2.0   11.420    1.098    1.000
# 2016-03-19   9.394   16.482    1.000      2.0   10.090    1.226    0.000
# 2016-03-20  13.858   15.444    5.000      1.0   18.648    0.000    2.000
# ...            ...      ...      ...      ...      ...      ...      ...
# 2018-12-30   7.042   10.946   15.000     30.0   12.702    0.000    3.690
# 2018-12-31   6.772   13.998   29.352     19.0   25.314    0.000    3.078
# 2016-03-28   0.000    2.684    6.000      2.0   11.822    0.000    1.000
# 2017-01-02   0.000    6.948    8.000      1.0   15.234    0.000    0.000
# 2018-10-07   0.000   21.882   18.000     20.0   42.564    0.000    1.000
#
#             UNITS_7  UNITS_8  UNITS_9  ...  UNITS_33  UNITS_34  UNITS_35  \
# ...

# %%
#reset columns
merged.columns = categories
merged
# Out:
#             Pumpkins  Citrus  Bunch Vegies  Sri Lankan Groceries  \
# DATENEW
# 2016-03-16     6.582  -0.420        10.020                   1.0
# 2016-03-17    12.104  22.956         2.150                   0.0
# 2016-03-18     8.496  13.878         3.000                   2.0
# 2016-03-19     9.394  16.482         1.000                   2.0
# 2016-03-20    13.858  15.444         5.000                   1.0
# ...              ...     ...           ...                   ...
# 2018-12-30     7.042  10.946        15.000                  30.0
# 2018-12-31     6.772  13.998        29.352                  19.0
# 2016-03-28     0.000   2.684         6.000                   2.0
# 2017-01-02     0.000   6.948         8.000                   1.0
# 2018-10-07     0.000  21.882        18.000                  20.0
#
#             Other Vegies  Veggies  Cabbages  Asian Vegies  Stonefruits  \
# DATENEW
# 2016-03-16         1.290    1.000     0.000         0.000        0.000
# ...

# %% [markdown]
# ## Visualize the series

# %%
# Plot the first 8
fig, axes = plt.subplots(nrows=4, ncols=2, dpi=120, figsize=(10,6))
temp = merged.iloc[:, :8]
for i, ax in enumerate(axes.flatten()):
    data = temp[temp.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(temp.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %% [markdown]
# There are some patterns in the graphs that is common amonst the 8 grpahs. Sri Lankan Groceries is a little out of the trend, as it's sale seems more stationary.

# %% [markdown]
# #  Testing Causation using Granger’s Causality Test

# %% [markdown]
# The null hypothesis is that a variable is not causing another. We set the significance level alpha = 0.05.

# %%
maxlag=21
test = 'ssr_chi2test'
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

grangers_causation_matrix(merged, variables = merged.columns)
# Out:
#                         Pumpkins_x  Citrus_x  Bunch Vegies_x  \
# Pumpkins_y                  1.0000    0.0000          0.0495
# Citrus_y                    0.0094    1.0000          0.0033
# Bunch Vegies_y              0.0002    0.0455          1.0000
# Sri Lankan Groceries_y      0.0090    0.0000          0.0188
# Other Vegies_y              0.1303    0.0003          0.0161
# Veggies_y                   0.0014    0.0000          0.0051
# Cabbages_y                  0.0027    0.1811          0.0023
# Asian Vegies_y              0.0075    0.0001          0.2095
# Stonefruits_y               0.0008    0.0000          0.0000
# Onions_y                    0.1859    0.0052          0.0283
# carrots_y                   0.0842    0.0500          0.2001
# Tropical Fruits_y           0.1593    0.0002          0.0005
# Melons_y                    0.0026    0.0000          0.0108
# Grapes_y                    0.0106    0.0039          0.0331
# ...

# %% [markdown]
# # Cointegration Test
# - a long run significant relationship between time series provided by cointegration is the premise for the VAR to work.

# %%
def cointegration_test(df, alpha=0.05): 
    """Perform Johanson's Cointegration Test and Report Summary"""
    out = coint_johansen(df,-1,5)
    d = {'0.90':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
    def adjust(val, length= 6): return str(val).ljust(length)

    # Summary
    print('Name   ::  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

cointegration_test(merged)
# Out:
# C:\Users\QYK\Anaconda3\lib\site-packages\statsmodels\tsa\vector_ar\vecm.py:608: HypothesisTestWarning: Critical values are only available for time series with 12 variables at most.
#   category=HypothesisTestWarning)
# Name   ::  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# Pumpkins ::  5768.48   > nan       =>   False
# Citrus ::  5399.37   > nan       =>   False
# Bunch Vegies ::  5034.05   > nan       =>   False
# Sri Lankan Groceries ::  4714.44   > nan       =>   False
# Other Vegies ::  4417.77   > nan       =>   False
# Veggies ::  4145.2    > nan       =>   False
# Cabbages ::  3887.48   > nan       =>   False
# Asian Vegies ::  3638.68   > nan       =>   False
# Stonefruits ::  3405.13   > nan       =>   False
# Onions ::  3193.38   > nan       =>   False
# carrots ::  2992.7    > nan       =>   False
# Tropical Fruits ::  2794.34   > nan       =>   False
# Melons ::  2608.19   > nan       =>   False
# ...

# %% [markdown]
# # Test for Stationarity (ADF)

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
# ADF Test on each column
for name, column in merged.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "Pumpkins"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.9647
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.437
#  Critical value 5%     = -2.864
#  Critical value 10%    = -2.568
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Citrus"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.6147
#  No. Lags Chosen       = 20
#  Critical value 1%     = -3.437
#  Critical value 5%     = -2.864
#  Critical value 10%    = -2.568
#  => P-Value = 0.4755. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Bunch Vegies"
# ...

# %%
# 1st difference
df_differenced = merged.diff().dropna()

# %%
# ADF Test on each column of 1st Differences Dataframe
for name, column in df_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "Pumpkins"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -10.7248
#  No. Lags Chosen       = 19
#  Critical value 1%     = -3.437
#  Critical value 5%     = -2.864
#  Critical value 10%    = -2.568
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Citrus"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -11.0976
#  No. Lags Chosen       = 19
#  Critical value 1%     = -3.437
#  Critical value 5%     = -2.864
#  Critical value 10%    = -2.568
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Bunch Vegies"
#     -----------------------------------------------
# ...

# %% [markdown]
# Now all series are stationary.

# %% [markdown]
# # Model Building

# %% [markdown]
# Check different estimates.

# %%
model = VAR(df_differenced)
for i in [1,2,3,4,5,6,7,8,9]:
    result = model.fit(i)
    print('Lag Order =', i)
    print('AIC : ', result.aic)
    print('BIC : ', result.bic)
    print('FPE : ', result.fpe)
    print('HQIC: ', result.hqic, '\n')
# Out:
# C:\Users\QYK\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# Lag Order = 1
# AIC :  125.31499274028455
# BIC :  134.59307869679245
# FPE :  2.6586943995521717e+54
# HQIC:  128.841141741209
#
# Lag Order = 2
# AIC :  122.9272937861045
# BIC :  141.2872062847767
# FPE :  2.4824528853557816e+53
# HQIC:  129.9053416852645
#
# Lag Order = 3
# AIC :  122.38492540758297
# BIC :  149.84114083565646
# FPE :  1.5094346243159261e+53
# HQIC:  132.82070991945454
#
# Lag Order = 4
# AIC :  122.64479333412491
# BIC :  159.2118260219816
# FPE :  2.137970033757589e+53
# HQIC:  136.54416787386972
#
# Lag Order = 5
# AIC :  123.06588114147121
# BIC :  168.7582834999522
# FPE :  3.7767965138766604e+53
# HQIC:  140.43471488258007
#
# Lag Order = 6
# AIC :  123.46933502323961
# ...

# %%
x = model.select_order(maxlags=12)
x.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Since both AIC and FPE chose lag = 3 to be the optiomal lag order, let's train our model using lag = 3.

# %%
model_fitted = model.fit(3)
model_fitted.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 24, Feb, 2020
# Time:                     14:21:07
# --------------------------------------------------------------------
# No. of Equations:         43.0000    BIC:                    149.841
# Nobs:                     999.000    HQIC:                   132.821
# Log likelihood:          -116495.    FPE:                1.50943e+53
# AIC:                      122.385    Det(Omega_mle):     7.83954e+50
# --------------------------------------------------------------------
# Results for equation Pumpkins
# ...
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                          -0.016824         0.213248           -0.079           0.937
# ...

# %% [markdown]
# # Check for Serial Correlation of Residuals (Errors) using Durbin Watson Statistic

# %% [markdown]
# Checking for serial correlation is to ensure that the model is sufficiently able to explain the variances and patterns in the time series.

# %% [markdown]
# The value of this statistic can vary between 0 and 4. The closer it is to the value 2, then there is no significant serial correlation. The closer to 0, there is a positive serial correlation, and the closer it is to 4 implies negative serial correlation.

# %%
out = durbin_watson(model_fitted.resid)

for col, val in zip(df_differenced.columns, out):
    print(col, ':', round(val, 2))
# Out:
# Pumpkins : 2.07
# Citrus : 2.04
# Bunch Vegies : 2.05
# Sri Lankan Groceries : 2.1
# Other Vegies : 2.07
# Veggies : 2.08
# Cabbages : 2.06
# Asian Vegies : 2.07
# Stonefruits : 2.03
# Onions : 2.11
# carrots : 2.11
# Tropical Fruits : 2.03
# Melons : 2.08
# Grapes : 2.07
# Potatoes : 2.02
# Tomatoes : 2.06
# Cucumbers : 2.07
# Bananas : 2.09
# Apples : 2.11
# Pears : 2.0
# Chillies : 2.13
# Other Fruits : 2.08
# Nuts : 2.08
# Herbs : 2.1
# Mushrooms : 2.08
# Lettuces : 2.08
# capsicum : 2.03
# Root Vegies : 2.09
# Multi buy : 2.01
# Eggs : 2.09
# Avocadoes : 2.05
# Berries : 2.04
# Cut Veggies : 2.07
# Flowers : 2.09
# Olympian Products : 2.07
# Groceries-Dry Goods : 2.05
# Cut Fruits : 2.02
# Kalamata olives : 2.06
# coconut Products : 2.12
# Fruits : 2.03
# trutaste : 2.09
# Pastas : 2.11
# markdown bag : 2.0

# %% [markdown]
# The serial correlations are all very close to 2, so we are good.

# %% [markdown]
# # Forecast

# %%
#clean the test dataset
base = get_cate(test, 'Pumpkins')
base = select_cols(base)
index = 1
for cate in categories:
    if cate != 'Pumpkins':
        other = get_cate(test, cate)
        other = select_cols(other)
        base = merge_dfs(base, other, index)
        index += 1
test_merged = base
test_merged
# Out:
#        DATENEW   UNITS  UNITS_1  UNITS_2  UNITS_3  UNITS_4  UNITS_5  UNITS_6  \
# 0   2019-01-02  15.202    8.320   15.000     11.0   22.958    0.000    0.000
# 1   2019-01-03  10.682    9.140   13.062      5.0   27.528    0.000    5.576
# 2   2019-01-04   5.164    4.404   16.000     11.0   12.664    0.000    4.340
# 3   2019-01-05  16.858    5.200   21.000     16.0   31.194    0.000    1.978
# 4   2019-01-06   8.602    9.196   17.000     27.0   15.332    0.000    7.298
# ..         ...     ...      ...      ...      ...      ...      ...      ...
# 272 2019-10-09   8.900   28.106   19.000      6.0   26.002    0.000    1.000
# 273 2019-10-10   4.346   15.860   38.000     24.0   30.056    0.204    1.574
# 274 2019-10-11   8.514   25.514   39.000     13.0   21.448    0.038    4.506
# 275 2019-10-12  12.140   19.698   54.000     14.0   47.556    2.126    5.500
# 276 2019-10-13   8.870    9.958   26.000     19.0   20.296    0.000    2.874
#
# ...

# %%
#reset index
test_merged = test_merged.set_index('DATENEW')
#reset columns
test_merged.columns = categories
test_merged
# Out:
#             Pumpkins  Citrus  Bunch Vegies  Sri Lankan Groceries  \
# DATENEW
# 2019-01-02    15.202   8.320        15.000                  11.0
# 2019-01-03    10.682   9.140        13.062                   5.0
# 2019-01-04     5.164   4.404        16.000                  11.0
# 2019-01-05    16.858   5.200        21.000                  16.0
# 2019-01-06     8.602   9.196        17.000                  27.0
# ...              ...     ...           ...                   ...
# 2019-10-09     8.900  28.106        19.000                   6.0
# 2019-10-10     4.346  15.860        38.000                  24.0
# 2019-10-11     8.514  25.514        39.000                  13.0
# 2019-10-12    12.140  19.698        54.000                  14.0
# 2019-10-13     8.870   9.958        26.000                  19.0
#
#             Other Vegies  Veggies  Cabbages  Asian Vegies  Stonefruits  \
# DATENEW
# 2019-01-02        22.958    0.000     0.000         6.726       28.126
# ...

# %%
# Get the lag order
lag_order = model_fitted.k_ar
print(lag_order)  #> 4

# Input data for forecasting
forecast_input = df_differenced.values[-lag_order:]
forecast_input
# Out:
# 3
# array([[-6.7720e+00, -1.1314e+01, -2.3352e+01, -1.7000e+01, -1.3492e+01,
#          0.0000e+00, -2.0780e+00, -6.8680e+00, -5.7660e+00, -6.1400e+00,
#         -3.8460e+00,  2.0900e+00, -6.7338e+01, -9.4000e-01, -7.7860e+00,
#         -1.0700e+01, -6.8880e+00, -2.8260e+01, -5.2320e+00, -2.2260e+00,
#         -1.9800e+00,  2.8440e+00,  1.0000e+00, -2.1190e+01, -2.8400e+00,
#         -4.9840e+00,  3.8200e-01, -1.6400e-01, -5.0000e+00, -1.5000e+01,
#         -3.0000e+00, -4.0000e+00, -4.0000e+00, -2.0000e+00,  0.0000e+00,
#         -1.3000e+01, -2.0000e+00, -1.0000e+00, -2.0000e+00, -3.1000e+01,
#         -1.0000e+00, -6.0000e+00,  0.0000e+00],
#        [ 0.0000e+00,  4.2640e+00,  2.0000e+00, -1.0000e+00,  3.4120e+00,
#          0.0000e+00, -1.0000e+00, -3.3540e+00, -2.9540e+00, -8.9340e+00,
#         -5.7180e+00, -1.4152e+01, -2.1640e+00, -5.4680e+00, -4.1200e+00,
#         -5.7340e+00,  2.1800e-01,  3.9940e+00,  1.0380e+00, -5.3000e-01,
# ...

# %%
# Forecast
nobs = len(test_merged)
fc = model_fitted.forecast(y = forecast_input, steps = nobs)
df_forecast = pd.DataFrame(fc, index = test_merged.index[ - nobs:], columns = df_differenced.columns + '_2d')
df_forecast
# Out:
#             Pumpkins_2d  Citrus_2d  Bunch Vegies_2d  Sri Lankan Groceries_2d  \
# DATENEW
# 2019-01-02     4.114742 -10.269868         1.076166               -10.319823
# 2019-01-03     0.527937  -1.111381        -9.254165                -3.268153
# 2019-01-04    -6.042102  -4.332102         2.193936                 1.272238
# 2019-01-05     1.816918   5.925337         2.810919                 4.280116
# 2019-01-06     1.148264  -1.255393        -0.865724                -3.941854
# ...                 ...        ...              ...                      ...
# 2019-10-09    -0.010509  -0.006109         0.009631                 0.007573
# 2019-10-10    -0.010509  -0.006109         0.009631                 0.007573
# 2019-10-11    -0.010509  -0.006109         0.009631                 0.007573
# 2019-10-12    -0.010509  -0.006109         0.009631                 0.007573
# 2019-10-13    -0.010509  -0.006109         0.009631                 0.007573
#
# ...

# %% [markdown]
# The prediction is on the scale of the training set, we need to de-defference it.

# %% [markdown]
# # Invert the transformation to get the real forecast

# %%
def invert_transformation(df_train, df_forecast, second_diff=False):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back 2nd Diff
        if second_diff:
            df_fc[str(col)+'_1d'] = (df_train[col].iloc[-1]-df_train[col].iloc[-2]) + df_fc[str(col)+'_2d'].cumsum()
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = df_train[col].iloc[-1] + df_fc[str(col)+'_1d'].cumsum()
    return df_fc

# %%
df_results = invert_transformation(merged, df_forecast, second_diff=True)        
df_results
# Out:
#             Pumpkins_2d  Citrus_2d  Bunch Vegies_2d  Sri Lankan Groceries_2d  \
# DATENEW
# 2019-01-02     4.114742 -10.269868         1.076166               -10.319823
# 2019-01-03     0.527937  -1.111381        -9.254165                -3.268153
# 2019-01-04    -6.042102  -4.332102         2.193936                 1.272238
# 2019-01-05     1.816918   5.925337         2.810919                 4.280116
# 2019-01-06     1.148264  -1.255393        -0.865724                -3.941854
# ...                 ...        ...              ...                      ...
# 2019-10-09    -0.010509  -0.006109         0.009631                 0.007573
# 2019-10-10    -0.010509  -0.006109         0.009631                 0.007573
# 2019-10-11    -0.010509  -0.006109         0.009631                 0.007573
# 2019-10-12    -0.010509  -0.006109         0.009631                 0.007573
# 2019-10-13    -0.010509  -0.006109         0.009631                 0.007573
#
# ...

# %%
forecast_categories = []
for cate in categories:
    forecast_categories.append(cate + '_forecast')
forecast_categories
# Out:
# ['Pumpkins_forecast',
#  'Citrus_forecast',
#  'Bunch Vegies_forecast',
#  'Sri Lankan Groceries_forecast',
#  'Other Vegies_forecast',
#  'Veggies_forecast',
#  'Cabbages_forecast',
#  'Asian Vegies_forecast',
#  'Stonefruits_forecast',
#  'Onions_forecast',
#  'carrots_forecast',
#  'Tropical Fruits_forecast',
#  'Melons_forecast',
#  'Grapes_forecast',
#  'Potatoes_forecast',
#  'Tomatoes_forecast',
#  'Cucumbers_forecast',
#  'Bananas_forecast',
#  'Apples_forecast',
#  'Pears_forecast',
#  'Chillies_forecast',
#  'Other Fruits_forecast',
#  'Nuts_forecast',
#  'Herbs_forecast',
#  'Mushrooms_forecast',
#  'Lettuces_forecast',
#  'capsicum_forecast',
#  'Root Vegies_forecast',
#  'Multi buy_forecast',
#  'Eggs_forecast',
#  'Avocadoes_forecast',
#  'Berries_forecast',
#  'Cut Veggies_forecast',
#  'Flowers_forecast',
#  'Olympian Products_forecast',
#  'Groceries-Dry Goods_forecast',
#  'Cut Fruits_forecast',
#  'Kalamata olives_forecast',
#  'coconut Products_forecast',
# ...

# %%
df_results[forecast_categories]
# Out:
#             Pumpkins_forecast  Citrus_forecast  Bunch Vegies_forecast  \
# DATENEW
# 2019-01-02           4.114742        26.546132              29.076166
# 2019-01-03           8.757420        30.098883              30.898166
# 2019-01-04           7.357997        29.319531              34.914103
# 2019-01-05           7.775492        34.465517              41.740959
# 2019-01-06           9.341251        38.356109              47.702091
# ...                       ...              ...                    ...
# 2019-10-09          22.742032       812.865805            1925.062118
# 2019-10-10          21.375138       814.932664            1933.362612
# 2019-10-11          19.997735       816.993413            1941.672736
# 2019-10-12          18.609822       819.048052            1949.992491
# 2019-10-13          17.211400       821.096582            1958.321877
#
#             Sri Lankan Groceries_forecast  Other Vegies_forecast  \
# DATENEW
# ...

# %% [markdown]
# # Plot of Forecast vs Actuals

# %%
fig, axes = plt.subplots(nrows=int(len(merged.columns)/2), ncols=2, dpi=150, figsize=(30,30))
for i, (col,ax) in enumerate(zip(merged.columns, axes.flatten())):
    df_results[col+'_forecast'].plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    test_merged[col][-nobs:].plot(legend=True, ax=ax)
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)
plt.show()

# %% [markdown]
# # Evaluate the Forecasts

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'corr':corr, 'minmax':minmax})

for cate in categories:
    print('Forecast Accuracy of: ' + cate)
    accuracy_prod = forecast_accuracy(df_results[cate + '_forecast'].values, test_merged[cate])
    for k, v in accuracy_prod.items():
        print(k, ': ', round(v,4))
# Out:
# Forecast Accuracy of: Pumpkins
# mape :  6.8115
# me :  64.5408
# mae :  64.7069
# mpe :  6.8005
# rmse :  70.7825
# corr :  0.2814
# minmax :  0.8049
# Forecast Accuracy of: Citrus
# mape :  24.9136
# me :  439.4322
# mae :  439.4322
# mpe :  24.9136
# rmse :  493.3547
# corr :  0.5705
# minmax :  0.9431
# Forecast Accuracy of: Bunch Vegies
# mape :  43.3357
# me :  908.1185
# mae :  908.1185
# mpe :  43.3357
# rmse :  1065.969
# corr :  0.3004
# minmax :  0.9497
# Forecast Accuracy of: Sri Lankan Groceries
# mape :  120.2812
# me :  1240.5951
# mae :  1240.5951
# mpe :  120.2812
# rmse :  1445.2031
# corr :  -0.1976
# minmax :  0.9722
# Forecast Accuracy of: Other Vegies
# mape :  75.1381
# me :  2088.0319
# mae :  2088.0319
# mpe :  75.1381
# rmse :  2432.7251
# corr :  0.0612
# minmax :  0.9694
# Forecast Accuracy of: Veggies
# mape :  inf
# me :  -26.5567
# mae :  26.557
# mpe :  nan
# rmse :  33.5571
# corr :  -0.0751
# minmax :  inf
# Forecast Accuracy of: Cabbages
# ...
