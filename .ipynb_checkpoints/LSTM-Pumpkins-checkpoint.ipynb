# %%
import numpy as np
import pandas as pd
import datetime
import timeit
import os
import csv
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
def convert_date(str):
    """
    This method is used to convert a string into datetime.
    """
    arr = str.split("-")
    year = int(arr[0])
    month = int(arr[1])

    str = arr[2]
    arr = str.split()
    day = int(arr[0])
    date = datetime.datetime(year = year, month = month, day = day)
    return date

# %% [markdown]
# ## Get Data

# %%
data = pd.read_csv("data/train.csv")
test = pd.read_csv('data/test.csv')
display(data.head())
display(test.head())
# Out:
#                                  TICKET  UNITS      PRICE  REFERENCE  \
# 0  d9ea23a9-8a1b-41b4-b554-2bf7e96ca2d9  3.292   0.000000       1079
# 1  d9ea23a9-8a1b-41b4-b554-2bf7e96ca2d9  0.290   0.000000       2032
# 2  f4dd518d-1fd8-4339-abc6-2c5390c20e30 -1.000   0.000000       2032
# 3  aa299de6-1332-48ba-bce9-de8cbb48741e  3.292  10.909091       1001
# 4  aa299de6-1332-48ba-bce9-de8cbb48741e  1.000   0.000000       4019
#
#            CODE                         NAME  PRICEBUY  PRICESELL  \
# 0  1.079000e+03        Pumpkin Japanese/Kent       0.0       1.99
# 1  2.032000e+03                 Orange navel       0.0       2.99
# 2  2.032000e+03                 Orange navel       0.0       2.99
# 3  1.001000e+03   Australian Asparagus green       2.0       2.70
# 4  8.888101e+12            Nice Munchee 200g       0.9       1.50
#
#                DATENEW     PAYMENT   TOTAL TRANSID             CATERGORY
# 0  2016-03-16 23:15:39        cash   0.000   no ID              Pumpkins
# 1  2016-03-16 23:15:39        cash   0.000   no ID                Citrus
# 2  2016-03-16 23:17:35  cashrefund   0.000     NaN                Citrus
# 3  2016-03-16 23:19:47        cash  39.504   no ID          Bunch Vegies
# 4  2016-03-16 23:19:47        cash  39.504   no ID  Sri Lankan Groceries
#                                  TICKET  UNITS  PRICE  REFERENCE    CODE  \
# 0  7394a47a-778b-4299-bc0b-204c803204fd  1.980   1.99       2010  2010.0
# 1  17079ce3-7a0b-4fbb-a762-977a3ae79667  1.000   1.50       1049  1049.0
# 2  17079ce3-7a0b-4fbb-a762-977a3ae79667  0.170   2.00       1071  1071.0
# 3  17079ce3-7a0b-4fbb-a762-977a3ae79667  1.044   2.50       1078  1078.0
# 4  17079ce3-7a0b-4fbb-a762-977a3ae79667  0.724   1.99       2003  2003.0
#
#                 NAME  PRICEBUY  PRICESELL              DATENEW PAYMENT  \
# 0   Banana Cavendish      2.00       1.99  2019-01-02 08:09:57    cash
# 1    Lettuce Iceberg      0.00       2.50  2019-01-02 08:34:09    cash
# 2     Potato brushed      2.25       2.50  2019-01-02 08:34:09    cash
# 3  Pumpkin Butternut      0.00       1.99  2019-01-02 08:34:09    cash
# 4   Apples Pink Lady      0.00       2.99  2019-01-02 08:34:09    cash
#
#       TOTAL TRANSID CATERGORY
# 0   3.95020   no ID   Bananas
# 1  14.49868   no ID  Lettuces
# 2  14.49868   no ID  Potatoes
# 3  14.49868   no ID  Pumpkins
# 4  14.49868   no ID    Apples

# %% [markdown]
# ## Column selection and categorization

# %%
data = data.loc[data['CATERGORY'] == 'Pumpkins']
data
# Out:
#                                       TICKET  UNITS  PRICE  REFERENCE    CODE  \
# 0       d9ea23a9-8a1b-41b4-b554-2bf7e96ca2d9  3.292    0.0       1079  1079.0
# 9       4b5e95b3-8a90-4e3a-8bf4-688c47f3b042  3.290    0.0       1079  1079.0
# 132     c787c6a0-6b58-464f-b085-d3165bf95879  3.608    0.9       1079  1079.0
# 140     a150c94c-d988-4cb1-9b83-45f6d6d154b9  2.346    0.9       1079  1079.0
# 202     a03ed49b-1609-47b4-ba39-38c1313c0bf8  1.852    2.0       1078  1078.0
# ...                                      ...    ...    ...        ...     ...
# 529473  87873c2c-0ad1-40dc-87eb-35f40ac41097  1.050    1.9       1080  1080.0
# 529529  92ad24e6-7d31-4afd-a35b-96b19bd6ca78  1.370    1.9       1080  1080.0
# 529687  5ae24124-3536-40c3-8dea-1ea2cd2625e9  0.978    1.2       1079  1079.0
# 529826  ec7c744f-72ae-464f-add1-7c7231200cc6  0.780    1.2       1079  1079.0
# 529955  19ebd170-5662-44aa-9af6-ef3bc81c994c  0.848    1.2       1079  1079.0
#
#                          NAME  PRICEBUY  PRICESELL              DATENEW  \
# 0       Pumpkin Japanese/Kent       0.0       1.99  2016-03-16 23:15:39
# 9       Pumpkin Japanese/Kent       0.0       1.99  2016-03-16 23:35:25
# 132     Pumpkin Japanese/Kent       0.0       1.99  2016-03-17 11:31:46
# 140     Pumpkin Japanese/Kent       0.0       1.99  2016-03-17 11:38:57
# 202         Pumpkin Butternut       0.0       1.99  2016-03-17 12:20:52
# ...                       ...       ...        ...                  ...
# 529473           Pumpkin Grey       0.0       1.99  2018-12-31 09:42:49
# 529529           Pumpkin Grey       0.0       1.99  2018-12-31 10:44:00
# 529687  Pumpkin Japanese/Kent       0.0       1.99  2018-12-31 12:48:36
# 529826  Pumpkin Japanese/Kent       0.0       1.99  2018-12-31 15:15:52
# 529955  Pumpkin Japanese/Kent       0.0       1.99  2018-12-31 18:35:58
#
#         PAYMENT     TOTAL       TRANSID CATERGORY
# 0          cash   0.00000         no ID  Pumpkins
# 9          cash   1.45000         no ID  Pumpkins
# 132        cash  19.35540         no ID  Pumpkins
# 140        cash  10.41156         no ID  Pumpkins
# 202        cash  15.72464         no ID  Pumpkins
# ...         ...       ...           ...       ...
# 529473     cash   7.45072         no ID  Pumpkins
# 529529     cash  20.69844         no ID  Pumpkins
# 529687     cash  18.90196         no ID  Pumpkins
# 529826     cash   2.74786         no ID  Pumpkins
# 529955  magcard  14.30234  756916459083  Pumpkins
#
# [11378 rows x 13 columns]

# %% [markdown]
# ### Sort by date and assign number to it

# %%
date = data['DATENEW'].apply(convert_date)
date
# Out:
# 0        2016-03-16
# 9        2016-03-16
# 132      2016-03-17
# 140      2016-03-17
# 202      2016-03-17
#             ...
# 529473   2018-12-31
# 529529   2018-12-31
# 529687   2018-12-31
# 529826   2018-12-31
# 529955   2018-12-31
# Name: DATENEW, Length: 11378, dtype: datetime64[ns]

# %%
data['DATENEW'] = date
data = data[["DATENEW", "UNITS"]].groupby('DATENEW').sum().reset_index()
data = data.sort_values(by = "DATENEW", ascending = True)
data
# Out:
#        DATENEW   UNITS
# 0   2016-03-16   6.582
# 1   2016-03-17  12.104
# 2   2016-03-18   8.496
# 3   2016-03-19   9.394
# 4   2016-03-20  13.858
# ..         ...     ...
# 995 2018-12-24  16.461
# 996 2018-12-28   7.174
# 997 2018-12-29  12.692
# 998 2018-12-30   7.042
# 999 2018-12-31   6.772
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## Building Model

# %%
test_df = test.loc[test['CATERGORY'] == 'Pumpkins']
test_df
# Out:
#                                       TICKET  UNITS  PRICE  REFERENCE    CODE  \
# 3       17079ce3-7a0b-4fbb-a762-977a3ae79667  1.044    2.5       1078  1078.0
# 26      95ab7fce-1164-48a2-8783-0977dfde35ae  0.830    1.2       1079  1079.0
# 46      1c35de1f-da99-4a7e-83be-c5cbbbb723d7  0.694    1.2       1079  1079.0
# 115     b418994a-69c6-4d57-b944-07cd16d76370  1.830    1.2       1079  1079.0
# 147     3ae20864-cf50-42a8-b15e-431c6cd4da03  1.268    2.5       1078  1078.0
# ...                                      ...    ...    ...        ...     ...
# 129040  e63e7306-912a-4bd7-9100-29a0b9d04533  0.912    2.4       1078  1078.0
# 129138  bc0f97ca-efb5-404a-8927-416aad1976b2  0.806    1.5       1079  1079.0
# 129188  668fc6a3-40ec-4af7-9188-bf94895675e4  0.992    1.5       1079  1079.0
# 129201  1648444a-ea34-4da5-964e-b31c2922cfe7  1.686    1.5       1079  1079.0
# 129209  9374097f-d3da-454c-a222-9f69721eeaa2  0.804    2.4       1078  1078.0
#
#                          NAME  PRICEBUY  PRICESELL              DATENEW  \
# 3           Pumpkin Butternut       0.0       1.99  2019-01-02 08:34:09
# 26      Pumpkin Japanese/Kent       0.0       1.99  2019-01-02 09:16:44
# 46      Pumpkin Japanese/Kent       0.0       1.99  2019-01-02 09:19:19
# 115     Pumpkin Japanese/Kent       0.0       1.99  2019-01-02 10:36:07
# 147         Pumpkin Butternut       0.0       1.99  2019-01-02 11:02:24
# ...                       ...       ...        ...                  ...
# 129040      Pumpkin Butternut       0.0       1.99  2019-10-13 11:31:03
# 129138  Pumpkin Japanese/Kent       0.0       1.99  2019-10-13 14:12:01
# 129188  Pumpkin Japanese/Kent       0.0       1.99  2019-10-13 16:01:22
# 129201  Pumpkin Japanese/Kent       0.0       1.99  2019-10-13 16:04:03
# 129209      Pumpkin Butternut       0.0       1.99  2019-10-13 16:30:35
#
#         PAYMENT     TOTAL       TRANSID CATERGORY
# 3          cash  14.49868         no ID  Pumpkins
# 26         cash   8.85466         no ID  Pumpkins
# 46         cash   5.80472         no ID  Pumpkins
# 115        cash  16.44860         no ID  Pumpkins
# 147        cash   3.15000         no ID  Pumpkins
# ...         ...       ...           ...       ...
# 129040     cash  12.09880         no ID  Pumpkins
# 129138     cash   3.64556         no ID  Pumpkins
# 129188  magcard  30.40102  880304475478  Pumpkins
# 129201     cash  12.75100         no ID  Pumpkins
# 129209  magcard  11.09760  633796691765  Pumpkins
#
# [2919 rows x 13 columns]

# %%
date = test_df['DATENEW'].apply(convert_date)
test_df['DATENEW'] = date
test_df = test_df[["DATENEW", "UNITS"]].groupby('DATENEW').sum().reset_index()
test_df = test_df.sort_values(by = "DATENEW", ascending = True)
test_df
# Out:
# C:\Users\QYK\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        DATENEW   UNITS
# 0   2019-01-02  15.202
# 1   2019-01-03  10.682
# 2   2019-01-04   5.164
# 3   2019-01-05  16.858
# 4   2019-01-06   8.602
# ..         ...     ...
# 272 2019-10-09   8.900
# 273 2019-10-10   4.346
# 274 2019-10-11   8.514
# 275 2019-10-12  12.140
# 276 2019-10-13   8.870
#
# [277 rows x 2 columns]

# %% [markdown]
# ### Save datasets

# %%
data.set_index('DATENEW').to_csv('data/Pumpkins data.csv')

# %%
test_df.set_index('DATENEW').to_csv('data/Pumpkins test.csv')

# %%
# frame a sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df

# %%
# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return pd.Series(diff)
 
# invert differenced value
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

# scale train and test data to [-1, 1]
def scale(train, test):
    # fit scaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train)
    # transform train
    train = train.reshape(train.shape[0], train.shape[1])
    train_scaled = scaler.transform(train)
    # transform test
    test = test.reshape(test.shape[0], test.shape[1])
    test_scaled = scaler.transform(test)
    return scaler, train_scaled, test_scaled
 
# inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
    new_row = [x for x in X] + [value]
    array = np.array(new_row)
    array = array.reshape(1, len(array))
    inverted = scaler.inverse_transform(array)
    return inverted[0, -1]
 
# fit an LSTM network to training data
def fit_lstm(train, batch_size, nb_epoch, neurons):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    model = Sequential()
    model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    for i in range(nb_epoch):
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
        model.reset_states()
    return model
 
# make a one-step forecast
def forecast_lstm(model, batch_size, X):
    X = X.reshape(1, 1, len(X))
    yhat = model.predict(X, batch_size=batch_size)
    return yhat[0,0]
 
sale_series = data['UNITS']
# transform data to be stationary
train_raw_values = sale_series.values
diff_values = difference(train_raw_values, 1)
 
# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values, 1)
train = supervised.values

sale_series = test_df['UNITS']
# transform data to be stationary
test_raw_values = sale_series.values
diff_values = difference(test_raw_values, 1)
 
# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values, 1)
test = supervised.values

# %%
# transform the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)
 
# fit the model
lstm_model = fit_lstm(train_scaled, 1, 1, 4)
# forecast the entire training dataset to build up state for forecasting
predictions = list()
for i in range(len(train_scaled)):
    # make one-step forecast
    X, y = train_scaled[i, 0:-1], train_scaled[i, -1]
    yhat = forecast_lstm(lstm_model, 1, X)
    # invert scaling
    yhat = invert_scale(scaler, X, yhat)
    # invert differencing
    yhat = inverse_difference(train_raw_values, yhat, len(train_scaled)+1-i)
    # store forecast
    predictions.append(yhat)
    expected = train_raw_values[i]
rmse = np.sqrt(mean_squared_error(train_raw_values[:-1], predictions))
print('Train RMSE: %.3f' % rmse)
# Out:
# Train RMSE: 1.949

# %%
# cross validation on the test data
predictions = list()
for i in range(len(test_scaled)):
    # make one-step forecast
    X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
    yhat = forecast_lstm(lstm_model, 1, X)
    # invert scaling
    yhat = invert_scale(scaler, X, yhat)
    # invert differencing
    yhat = inverse_difference(test_raw_values, yhat, len(test_scaled)+1-i)
    # store forecast
    predictions.append(yhat)
    expected = test_raw_values[i]
    print('Predicted=%f, Expected=%f' % (yhat, expected))
# Out:
# Predicted=16.325057, Expected=15.202000
# Predicted=12.681852, Expected=10.682000
# Predicted=8.062475, Expected=5.164000
# Predicted=15.944535, Expected=16.858000
# Predicted=9.923242, Expected=8.602000
# Predicted=13.107260, Expected=13.330000
# Predicted=7.218699, Expected=5.434000
# Predicted=10.063861, Expected=9.862000
# Predicted=7.081911, Expected=5.942000
# Predicted=8.535449, Expected=8.260000
# Predicted=8.894760, Expected=8.818000
# Predicted=8.166588, Expected=7.850000
# Predicted=5.257490, Expected=4.050000
# Predicted=6.432105, Expected=6.006000
# Predicted=3.177196, Expected=1.788000
# Predicted=3.072537, Expected=2.096000
# Predicted=5.980240, Expected=6.314000
# Predicted=15.175215, Expected=18.526000
# Predicted=5.589124, Expected=5.024000
# Predicted=8.428669, Expected=8.950000
# Predicted=5.775120, Expected=5.226000
# Predicted=10.291747, Expected=11.424000
# Predicted=6.616522, Expected=6.172000
# Predicted=8.436571, Expected=8.710000
# Predicted=10.589544, Expected=11.464000
# Predicted=5.440976, Expected=4.330000
# Predicted=7.450264, Expected=7.358000
# Predicted=7.821329, Expected=7.854000
# Predicted=15.152580, Expected=17.640000
# Predicted=8.485854, Expected=8.100000
# Predicted=5.870454, Expected=4.684000
# Predicted=4.949664, Expected=3.806000
# Predicted=12.209275, Expected=13.934000
# Predicted=3.524705, Expected=1.972000
# Predicted=6.967625, Expected=7.110000
# Predicted=6.897654, Expected=6.950000
# Predicted=14.689874, Expected=17.352000
# Predicted=8.283653, Expected=8.110000
# Predicted=12.733506, Expected=14.056000
# Predicted=8.660390, Expected=8.214000
# Predicted=11.285105, Expected=11.820000
# Predicted=16.322388, Expected=18.342000
# Predicted=13.186524, Expected=13.528000
# Predicted=9.391715, Expected=8.310000
# Predicted=14.213170, Expected=15.098000
# Predicted=8.659335, Expected=7.436000
# Predicted=8.626955, Expected=7.768000
# Predicted=14.219279, Expected=15.542000
# Predicted=11.063919, Expected=10.922000
# Predicted=15.650314, Expected=17.066000
# Predicted=10.294840, Expected=9.512000
# Predicted=10.490588, Expected=9.986000
# Predicted=6.590146, Expected=4.918000
# Predicted=12.636045, Expected=13.608000
# Predicted=13.696871, Expected=14.706000
# Predicted=11.899110, Expected=11.950000
# Predicted=7.929416, Expected=6.608000
# Predicted=5.859275, Expected=4.244000
# Predicted=18.050270, Expected=21.210000
# Predicted=5.782354, Expected=4.340000
# Predicted=13.921455, Expected=15.776000
# Predicted=14.886450, Expected=16.484000
# Predicted=16.095283, Expected=17.522000
# Predicted=20.529228, Expected=22.902000
# Predicted=12.540714, Expected=11.640000
# Predicted=10.039375, Expected=8.544000
# Predicted=11.487624, Expected=10.944000
# Predicted=24.931454, Expected=29.162000
# Predicted=10.992352, Expected=9.946000
# Predicted=17.494870, Expected=19.004000
# Predicted=14.926449, Expected=15.104000
# Predicted=9.923328, Expected=8.356000
# Predicted=5.427023, Expected=2.850000
# Predicted=5.857112, Expected=4.292000
# Predicted=5.019882, Expected=3.672000
# Predicted=6.212823, Expected=5.720000
# Predicted=8.003464, Expected=8.276000
# Predicted=11.580870, Expected=12.962000
# Predicted=9.236380, Expected=9.388000
# Predicted=5.044538, Expected=3.720000
# Predicted=7.351945, Expected=7.224000
# Predicted=4.907490, Expected=3.982000
# Predicted=12.622959, Expected=14.644000
# Predicted=8.580741, Expected=8.680000
# Predicted=11.458322, Expected=12.436000
# Predicted=8.605163, Expected=8.302000
# Predicted=8.714155, Expected=8.496000
# Predicted=21.012932, Expected=25.026000
# Predicted=8.051741, Expected=7.098000
# Predicted=6.701968, Expected=5.570000
# Predicted=19.113929, Expected=22.614000
# Predicted=12.239819, Expected=12.602000
# Predicted=15.272305, Expected=16.458000
# Predicted=7.259418, Expected=5.486000
# Predicted=8.361093, Expected=7.540000
# Predicted=13.242016, Expected=14.342000
# Predicted=18.884153, Expected=21.510000
# Predicted=26.670045, Expected=30.988000
# Predicted=20.254262, Expected=21.280000
# Predicted=21.841373, Expected=22.920000
# Predicted=9.681734, Expected=6.616000
# Predicted=15.744747, Expected=15.862000
# Predicted=12.394261, Expected=11.330000
# Predicted=12.265235, Expected=11.488000
# Predicted=18.473146, Expected=20.074000
# Predicted=9.188765, Expected=7.346000
# Predicted=10.458685, Expected=9.670000
# Predicted=14.591302, Expected=15.460000
# Predicted=14.845941, Expected=15.502000
# Predicted=8.265000, Expected=6.542000
# Predicted=15.573362, Expected=16.952000
# Predicted=17.445090, Expected=19.008000
# Predicted=14.959684, Expected=15.168000
# Predicted=17.299109, Expected=18.160000
# Predicted=11.756387, Expected=10.508000
# Predicted=23.255936, Expected=26.360000
# Predicted=10.753869, Expected=9.196000
# Predicted=12.401459, Expected=11.918000
# Predicted=7.483596, Expected=5.500000
# Predicted=10.992547, Expected=10.892000
# Predicted=14.780853, Expected=15.994000
# Predicted=7.212635, Expected=5.600000
# Predicted=7.166705, Expected=6.066000
# Predicted=9.583174, Expected=9.656000
# Predicted=8.956692, Expected=8.778000
# Predicted=11.199668, Expected=11.812000
# Predicted=7.182461, Expected=6.254000
# Predicted=12.661570, Expected=13.892000
# Predicted=9.062987, Expected=8.720000
# Predicted=13.156292, Expected=14.272000
# Predicted=12.537031, Expected=13.066000
# Predicted=25.814753, Expected=30.589000
# Predicted=23.374269, Expected=26.050000
# Predicted=21.640940, Expected=22.776000
# Predicted=22.184711, Expected=23.026000
# Predicted=18.755842, Expected=18.138000
# Predicted=28.594745, Expected=31.480000
# Predicted=22.111565, Expected=22.086000
# Predicted=13.951776, Expected=11.250000
# Predicted=19.008799, Expected=18.988000
# Predicted=15.140779, Expected=13.814000
# Predicted=12.802025, Expected=11.108000
# Predicted=13.106773, Expected=12.070000
# Predicted=10.766504, Expected=9.262000
# Predicted=10.622833, Expected=9.562000
# Predicted=7.619789, Expected=5.882000
# Predicted=12.246698, Expected=12.704000
# Predicted=9.027963, Expected=8.272000
# Predicted=4.635562, Expected=2.646000
# Predicted=9.476898, Expected=9.840000
# Predicted=6.949542, Expected=6.358000
# Predicted=15.848770, Expected=18.498000
# Predicted=6.457539, Expected=5.418000
# Predicted=4.975693, Expected=3.748000
# Predicted=4.355620, Expected=3.298000
# Predicted=8.332157, Expected=8.978000
# Predicted=6.889047, Expected=6.840000
# Predicted=7.672064, Expected=7.870000
# Predicted=14.449614, Expected=16.854000
# Predicted=21.869782, Expected=25.948000
# Predicted=8.769555, Expected=7.760000
# Predicted=16.447220, Expected=18.326000
# Predicted=8.118836, Expected=6.792000
# Predicted=25.428146, Expected=30.449000
# Predicted=15.399584, Expected=16.118000
# Predicted=14.938208, Expected=15.174000
# Predicted=19.091284, Expected=20.592000
# Predicted=13.400336, Expected=12.562000
# Predicted=20.646974, Expected=22.534000
# Predicted=20.883086, Expected=22.234000
# Predicted=25.742173, Expected=28.202000
# Predicted=10.751556, Expected=7.952000
# Predicted=17.630030, Expected=18.224000
# Predicted=10.675813, Expected=8.802000
# Predicted=10.182802, Expected=8.768000
# Predicted=15.483841, Expected=16.368000
# Predicted=14.987117, Expected=15.410000
# Predicted=17.962951, Expected=19.211000
# Predicted=9.752508, Expected=7.960000
# Predicted=16.181488, Expected=17.206000
# Predicted=14.673149, Expected=14.862000
# Predicted=11.180456, Expected=10.110000
# Predicted=16.061000, Expected=16.992000
# Predicted=16.023355, Expected=16.624000
# Predicted=14.749860, Expected=14.686000
# Predicted=9.945223, Expected=8.278000
# Predicted=12.214085, Expected=11.858000
# Predicted=9.706503, Expected=8.602000
# Predicted=14.459113, Expected=15.342000
# Predicted=12.735484, Expected=12.754000
# Predicted=13.416073, Expected=13.616000
# Predicted=8.800592, Expected=7.386000
# Predicted=8.969620, Expected=8.056000
# Predicted=21.166785, Expected=24.754000
# Predicted=21.019473, Expected=23.535000
# Predicted=27.295225, Expected=30.958000
# Predicted=15.907387, Expected=15.026000
# Predicted=28.187151, Expected=31.703000
# Predicted=16.651446, Expected=15.694000
# Predicted=22.983720, Expected=24.466000
# Predicted=32.953799, Expected=37.262000
# Predicted=18.919430, Expected=17.850000
# Predicted=38.308371, Expected=44.124000
# Predicted=51.420216, Expected=59.725000
# Predicted=28.494287, Expected=28.764000
# Predicted=36.852828, Expected=39.700000
# Predicted=13.552922, Expected=9.094000
# Predicted=12.330593, Expected=9.230000
# Predicted=11.465546, Expected=9.072000
# Predicted=12.884414, Expected=11.794000
# Predicted=13.253344, Expected=12.642000
# Predicted=10.443376, Expected=9.068000
# Predicted=8.176855, Expected=6.478000
# Predicted=16.408943, Expected=18.170000
# Predicted=11.534949, Expected=11.176000
# Predicted=9.160157, Expected=8.086000
# Predicted=8.508346, Expected=7.538000
# Predicted=12.775926, Expected=13.572000
# Predicted=9.083635, Expected=8.398000
# Predicted=11.260184, Expected=11.508000
# Predicted=11.377288, Expected=11.556000
# Predicted=9.216226, Expected=8.582000
# Predicted=8.399730, Expected=7.662000
# Predicted=11.770080, Expected=12.398000
# Predicted=11.630573, Expected=11.988000
# Predicted=11.803253, Expected=12.060000
# Predicted=13.273468, Expected=13.896000
# Predicted=14.082014, Expected=14.730000
# Predicted=24.617501, Expected=28.556000
# Predicted=19.590329, Expected=20.812000
# Predicted=21.986886, Expected=23.480000
# Predicted=13.211231, Expected=11.428000
# Predicted=15.581998, Expected=15.170000
# Predicted=15.329013, Expected=14.926000
# Predicted=15.658637, Expected=15.464000
# Predicted=8.137231, Expected=5.526000
# Predicted=8.284766, Expected=6.616000
# Predicted=6.824039, Expected=5.192000
# Predicted=13.154095, Expected=14.284000
# Predicted=10.628268, Expected=10.574000
# Predicted=14.436324, Expected=15.660000
# Predicted=6.594585, Expected=4.914000
# Predicted=7.794951, Expected=7.068000
# Predicted=8.235949, Expected=7.874000
# Predicted=8.378939, Expected=8.162000
# Predicted=11.231301, Expected=12.030000
# Predicted=9.868279, Expected=9.936000
# Predicted=11.989913, Expected=12.706000
# Predicted=16.739265, Expected=18.782000
# Predicted=9.904408, Expected=9.122000
# Predicted=8.286337, Expected=7.166000
# Predicted=8.629533, Expected=7.958000
# Predicted=11.233924, Expected=11.644000
# Predicted=9.369807, Expected=9.004000
# Predicted=10.630642, Expected=10.776000
# Predicted=13.679758, Expected=14.776000
# Predicted=10.341030, Expected=9.966000
# Predicted=14.453277, Expected=15.550000
# Predicted=9.968290, Expected=9.234000
# Predicted=10.125939, Expected=9.642000
# Predicted=16.354601, Expected=18.128000
# Predicted=7.127417, Expected=5.444000
# Predicted=9.818051, Expected=9.608000
# Predicted=8.578961, Expected=7.996000
# Predicted=7.774464, Expected=7.084000
# Predicted=6.554839, Expected=5.654000
# Predicted=7.431123, Expected=7.104000
# Predicted=7.645570, Expected=7.476000
# Predicted=12.313644, Expected=13.766000
# Predicted=5.585974, Expected=4.414000
# Predicted=15.986124, Expected=18.768000
# Predicted=12.298387, Expected=13.088000
# Predicted=9.390945, Expected=8.900000
# Predicted=5.886282, Expected=4.346000
# Predicted=8.627894, Expected=8.514000
# Predicted=11.324075, Expected=12.140000

# %%
# report performance
rmse = np.sqrt(mean_squared_error(test_raw_values[:-1], predictions))
print('Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
plt.plot(test_raw_values[:-1])
plt.plot(predictions)
blue_patch = mpatches.Patch(color='blue', label='raw_values')
orange_patch = mpatches.Patch(color='orange', label='predictions')
plt.legend(handles=[blue_patch, orange_patch])
plt.ylabel('Units')
plt.xlabel('day')
plt.title('Forecast of Units Per Day')
plt.show()
# Out:
# Test RMSE: 2.893

# %% [markdown]
# ## Save to csv

# %%
pred_df = pd.DataFrame(predictions)
pred_df.index = test_df['DATENEW'][:-1]
pred_df.columns = ['Pumpkins']
pred_df
# Out:
#              Pumpkins
# DATENEW
# 2019-01-02  17.645791
# 2019-01-03  14.486812
# 2019-01-04  10.299777
# 2019-01-05  15.248390
# 2019-01-06  10.823526
# ...               ...
# 2019-10-08  11.832785
# 2019-10-09   9.905447
# 2019-10-10   7.147281
# 2019-10-11   8.820266
# 2019-10-12  10.840070
#
# [276 rows x 1 columns]

# %%
path = os.path.join('predictions', 'Pumpkins lstm prediction.csv')
pred_df.to_csv(path)

# %% [markdown]
# # Find Elbow Point

# %%
# fit an LSTM network to training data
test_code = '''
def fit_lstm(train, batch_size, nb_epoch, neurons):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    model = Sequential()
    model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    for i in range(nb_epoch):
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
        model.reset_states()
    return model
'''

# %%
batch_size = 1
result = pd.DataFrame(columns = ['time', 'rmse', 'nb_epoch', 'neurons'])
for nb_epoch in range(1, 11):
    for neurons in range(1, 11):
        #training part
        X, y = train_scaled[:, 0:-1], train_scaled[:, -1]
        X = X.reshape(X.shape[0], 1, X.shape[1])
        model = Sequential()
        model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
        model.add(Dense(1))
        model.compile(loss='mean_squared_error', optimizer='adam')
        test_code = '''
model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
model.reset_states()
        '''
        time_cost = timeit.repeat(stmt = test_code, setup = 'from __main__ import ' + ', '.join(globals()), repeat = nb_epoch, number = 1)
        
        #predicting part
        predictions = list()
        for i in range(len(test_scaled)):
            # make one-step forecast
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            yhat = forecast_lstm(model, 1, X)
            # invert scaling
            yhat = invert_scale(scaler, X, yhat)
            # invert differencing
            yhat = inverse_difference(test_raw_values, yhat, len(test_scaled)+1-i)
            # store forecast
            predictions.append(yhat)
            expected = test_raw_values[i]
        rmse = np.sqrt(mean_squared_error(test_raw_values[:-1], predictions))
        
        #append to result
        result = result.append(pd.DataFrame({'time': time_cost, 'rmse': rmse, 'nb_epoch': nb_epoch, 'neurons': neurons}))
result
# Out:
# [15.008795768790876, 10.32486289266497, 4.633399024128915, 16.915323070384563, 8.31143576063216, 13.286923098929226, 5.062467338487506, 9.743047620998697, 5.673615472875537, 8.13163551340066, 8.730200468314813, 7.730070458484815, 3.7828762330971673, 5.863301769137384, 1.48588691173494, 1.8556084716841594, 6.287949935093524, 19.007895818963647, 4.893973820356654, 8.99599944009632, 5.104353921493517, 11.576050964936616, 6.079772654259578, 8.730955715060235, 11.59321960643679, 4.132422470331193, 7.315810814745725, 7.835905621655286, 18.026617791011926, 8.040740494990722, 4.475913176916541, 3.590524237738924, 14.174290039844811, 1.684789600577207, 7.087754764623942, 6.923108961835505, 17.755915729105475, 8.080612604796888, 14.266249108143153, 8.146007848417387, 11.904739152111112, 18.68306132495404, 13.617057216897608, 8.147716845806688, 15.241810134038332, 7.236469293000178, 7.610148195013405, 15.732116420455277, 10.892626917250457, 17.28856046957523, 9.382976809116082, 9.889441259006041, 4.617302224360409, 13.721666020102798, 14.85383212988824, 11.949657605767252, 6.37130781131238, 3.942668008364739, 21.65618366959691, 4.060538370303811, 16.02190572617203, 16.73722682849318, 17.768123530782763, 23.324103297889238, 11.52405599808507, 8.304614829884844, 10.842241677192973, 29.81528875157238, 9.769735119162128, 19.227997557751838, 15.137496345795691, 8.085997490