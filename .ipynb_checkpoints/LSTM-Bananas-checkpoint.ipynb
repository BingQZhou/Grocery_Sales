# %%
import numpy as np
import pandas as pd
import datetime
import timeit
import os
import csv
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# Out:
# Using TensorFlow backend.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
def convert_date(str):
    """
    This method is used to convert a string into datetime.
    """
    arr = str.split("-")
    year = int(arr[0])
    month = int(arr[1])

    str = arr[2]
    arr = str.split()
    day = int(arr[0])
    date = datetime.datetime(year = year, month = month, day = day)
    return date

# %% [markdown]
# ## Get Data

# %%
data = pd.read_csv("data/train.csv")
test = pd.read_csv('data/test.csv')
display(data.head())
display(test.head())
# Out:
#                                  TICKET  UNITS      PRICE  REFERENCE  \
# 0  d9ea23a9-8a1b-41b4-b554-2bf7e96ca2d9  3.292   0.000000       1079
# 1  d9ea23a9-8a1b-41b4-b554-2bf7e96ca2d9  0.290   0.000000       2032
# 2  f4dd518d-1fd8-4339-abc6-2c5390c20e30 -1.000   0.000000       2032
# 3  aa299de6-1332-48ba-bce9-de8cbb48741e  3.292  10.909091       1001
# 4  aa299de6-1332-48ba-bce9-de8cbb48741e  1.000   0.000000       4019
#
#            CODE                         NAME  PRICEBUY  PRICESELL  \
# 0  1.079000e+03        Pumpkin Japanese/Kent       0.0       1.99
# 1  2.032000e+03                 Orange navel       0.0       2.99
# 2  2.032000e+03                 Orange navel       0.0       2.99
# 3  1.001000e+03   Australian Asparagus green       2.0       2.70
# 4  8.888101e+12            Nice Munchee 200g       0.9       1.50
#
#                DATENEW     PAYMENT   TOTAL TRANSID             CATERGORY
# 0  2016-03-16 23:15:39        cash   0.000   no ID              Pumpkins
# 1  2016-03-16 23:15:39        cash   0.000   no ID                Citrus
# 2  2016-03-16 23:17:35  cashrefund   0.000     NaN                Citrus
# 3  2016-03-16 23:19:47        cash  39.504   no ID          Bunch Vegies
# 4  2016-03-16 23:19:47        cash  39.504   no ID  Sri Lankan Groceries
#                                  TICKET  UNITS  PRICE  REFERENCE    CODE  \
# 0  7394a47a-778b-4299-bc0b-204c803204fd  1.980   1.99       2010  2010.0
# 1  17079ce3-7a0b-4fbb-a762-977a3ae79667  1.000   1.50       1049  1049.0
# 2  17079ce3-7a0b-4fbb-a762-977a3ae79667  0.170   2.00       1071  1071.0
# 3  17079ce3-7a0b-4fbb-a762-977a3ae79667  1.044   2.50       1078  1078.0
# 4  17079ce3-7a0b-4fbb-a762-977a3ae79667  0.724   1.99       2003  2003.0
#
#                 NAME  PRICEBUY  PRICESELL              DATENEW PAYMENT  \
# 0   Banana Cavendish      2.00       1.99  2019-01-02 08:09:57    cash
# 1    Lettuce Iceberg      0.00       2.50  2019-01-02 08:34:09    cash
# 2     Potato brushed      2.25       2.50  2019-01-02 08:34:09    cash
# 3  Pumpkin Butternut      0.00       1.99  2019-01-02 08:34:09    cash
# 4   Apples Pink Lady      0.00       2.99  2019-01-02 08:34:09    cash
#
#       TOTAL TRANSID CATERGORY
# 0   3.95020   no ID   Bananas
# 1  14.49868   no ID  Lettuces
# 2  14.49868   no ID  Potatoes
# 3  14.49868   no ID  Pumpkins
# 4  14.49868   no ID    Apples

# %% [markdown]
# ## Column selection and categorization

# %%
data = data.loc[data['CATERGORY'] == 'Bananas']
data
# Out:
#                                       TICKET  UNITS  PRICE  REFERENCE    CODE  \
# 47      71a47b20-65cf-44cf-b759-1e6a22894e54  1.292   1.59       2010  2010.0
# 59      fe6687ab-205a-4713-b07a-4319a36a6327  1.254   1.59       2010  2010.0
# 92      c1e1c457-80c8-4c5d-b384-ba68a0750d21  0.828   1.59       2010  2010.0
# 100     15a336e0-d1b8-4190-ae21-230c7b19175e  0.956   1.59       2010  2010.0
# 103     d24bbcd9-bfab-4e9f-a890-6382de2427f6  0.822   1.59       2010  2010.0
# ...                                      ...    ...    ...        ...     ...
# 529919  63cea9d3-dc7e-4de6-ae50-4bf8dc8b0de0  0.908   1.99       2010  2010.0
# 529936  20cbe698-ece6-419c-9a8f-89db911b7926  1.118   1.99       2010  2010.0
# 529951  4070f4d0-3763-424d-b9e4-ab68e662e5fa  1.524   1.99       2010  2010.0
# 529959  19ebd170-5662-44aa-9af6-ef3bc81c994c  0.926   1.99       2010  2010.0
# 529962  a67acaf1-92c0-4634-8623-6782f19a7444  0.388   1.99       2010  2010.0
#
#                     NAME  PRICEBUY  PRICESELL              DATENEW  PAYMENT  \
# 47      Banana Cavendish       2.0       1.99  2016-03-17 10:37:16     cash
# 59      Banana Cavendish       2.0       1.99  2016-03-17 10:46:28     cash
# 92      Banana Cavendish       2.0       1.99  2016-03-17 11:07:38     cash
# 100     Banana Cavendish       2.0       1.99  2016-03-17 11:10:34     cash
# 103     Banana Cavendish       2.0       1.99  2016-03-17 11:11:32  magcard
# ...                  ...       ...        ...                  ...      ...
# 529919  Banana Cavendish       2.0       1.99  2018-12-31 17:26:57     cash
# 529936  Banana Cavendish       2.0       1.99  2018-12-31 17:48:12  magcard
# 529951  Banana Cavendish       2.0       1.99  2018-12-31 18:20:24     cash
# 529959  Banana Cavendish       2.0       1.99  2018-12-31 18:35:58  magcard
# 529962  Banana Cavendish       2.0       1.99  2018-12-31 18:36:34     cash
#
#             TOTAL       TRANSID CATERGORY
# 47       5.336462         no ID   Bananas
# 59      20.067160         no ID   Bananas
# 92      62.437462         no ID   Bananas
# 100      6.006880         no ID   Bananas
# 103      3.623580  482881061639   Bananas
# ...           ...           ...       ...
# 529919  13.749700         no ID   Bananas
# 529936  22.246160  891189246880   Bananas
# 529951  20.552760         no ID   Bananas
# 529959  14.302340  756916459083   Bananas
# 529962   0.752120         no ID   Bananas
#
# [36779 rows x 13 columns]

# %% [markdown]
# ### Sort by date and assign number to it

# %%
date = data['DATENEW'].apply(convert_date)
date
# Out:
# 47       2016-03-17
# 59       2016-03-17
# 92       2016-03-17
# 100      2016-03-17
# 103      2016-03-17
#             ...
# 529919   2018-12-31
# 529936   2018-12-31
# 529951   2018-12-31
# 529959   2018-12-31
# 529962   2018-12-31
# Name: DATENEW, Length: 36779, dtype: datetime64[ns]

# %%
data['DATENEW'] = date
data = data[["DATENEW", "UNITS"]].groupby('DATENEW').sum().reset_index()
data = data.sort_values(by = "DATENEW", ascending = True)
data
# Out:
#         DATENEW   UNITS
# 0    2016-03-17  21.344
# 1    2016-03-18  20.408
# 2    2016-03-19  30.732
# 3    2016-03-20  16.268
# 4    2016-03-21  21.618
# ...         ...     ...
# 997  2018-12-24  27.786
# 998  2018-12-28  12.200
# 999  2018-12-29  25.734
# 1000 2018-12-30  18.176
# 1001 2018-12-31  38.168
#
# [1002 rows x 2 columns]

# %% [markdown]
# ## Building Model

# %%
test_df = test.loc[test['CATERGORY'] == 'Bananas']
test_df
# Out:
#                                       TICKET  UNITS  PRICE  REFERENCE    CODE  \
# 0       7394a47a-778b-4299-bc0b-204c803204fd  1.980   1.99       2010  2010.0
# 8       17079ce3-7a0b-4fbb-a762-977a3ae79667  1.082   1.99       2010  2010.0
# 10      aa078592-0d13-48ff-9d74-3bc75892011e  1.116   1.99       2010  2010.0
# 15      810e59b8-d23a-479d-b4d8-81bcd05953cb  0.710   1.99       2010  2010.0
# 27      95ab7fce-1164-48a2-8783-0977dfde35ae  0.934   1.99       2010  2010.0
# ...                                      ...    ...    ...        ...     ...
# 129134  45b5b4d2-0c2f-4a56-8ffd-cd3e192c6c9e  0.746   3.50       2010  2010.0
# 129154  ce3e4720-9219-4e50-88de-cbe178f4044d  1.444   3.50       2010  2010.0
# 129193  668fc6a3-40ec-4af7-9188-bf94895675e4  0.894   3.50       2010  2010.0
# 129210  9374097f-d3da-454c-a222-9f69721eeaa2  1.188   3.50       2010  2010.0
# 129241  5cb041e2-1976-45b4-ba06-7779d6893156  1.042   3.50       2010  2010.0
#
#                     NAME  PRICEBUY  PRICESELL              DATENEW  PAYMENT  \
# 0       Banana Cavendish       2.0       1.99  2019-01-02 08:09:57     cash
# 8       Banana Cavendish       2.0       1.99  2019-01-02 08:34:09     cash
# 10      Banana Cavendish       2.0       1.99  2019-01-02 08:35:23     cash
# 15      Banana Cavendish       2.0       1.99  2019-01-02 08:36:40     cash
# 27      Banana Cavendish       2.0       1.99  2019-01-02 09:16:44     cash
# ...                  ...       ...        ...                  ...      ...
# 129134  Banana Cavendish       2.0       1.99  2019-10-13 13:24:56     cash
# 129154  Banana Cavendish       2.0       1.99  2019-10-13 15:06:34  magcard
# 129193  Banana Cavendish       2.0       1.99  2019-10-13 16:01:22  magcard
# 129210  Banana Cavendish       2.0       1.99  2019-10-13 16:30:35  magcard
# 129241  Banana Cavendish       2.0       1.99  2019-10-13 17:41:45  magcard
#
#            TOTAL       TRANSID CATERGORY
# 0        3.95020         no ID   Bananas
# 8       14.49868         no ID   Bananas
# 10      11.70084         no ID   Bananas
# 15       9.04570         no ID   Bananas
# 27       8.85466         no ID   Bananas
# ...          ...           ...       ...
# 129134   5.49542         no ID   Bananas
# 129154  22.94530  592150417280   Bananas
# 129193  30.40102  880304475478   Bananas
# 129210  11.09760  633796691765   Bananas
# 129241  33.54912  904210501806   Bananas
#
# [7188 rows x 13 columns]

# %%
date = test_df['DATENEW'].apply(convert_date)
test_df['DATENEW'] = date
test_df = test_df[["DATENEW", "UNITS"]].groupby('DATENEW').sum().reset_index()
test_df = test_df.sort_values(by = "DATENEW", ascending = True)
test_df
# Out:
# C:\Users\QYK\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        DATENEW   UNITS
# 0   2019-01-02  52.330
# 1   2019-01-03  30.684
# 2   2019-01-04  23.248
# 3   2019-01-05  32.950
# 4   2019-01-06  17.636
# ..         ...     ...
# 272 2019-10-09  16.128
# 273 2019-10-10  20.832
# 274 2019-10-11  18.468
# 275 2019-10-12  15.384
# 276 2019-10-13  13.944
#
# [277 rows x 2 columns]

# %% [markdown]
# ### Save datasets

# %%
data.set_index('DATENEW').to_csv('data/Bananas data.csv')

# %%
test_df.set_index('DATENEW').to_csv('data/Bananas test.csv')

# %%
# frame a sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df

# %%
# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return pd.Series(diff)
 
# invert differenced value
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

# scale train and test data to [-1, 1]
def scale(train, test):
    # fit scaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train)
    # transform train
    train = train.reshape(train.shape[0], train.shape[1])
    train_scaled = scaler.transform(train)
    # transform test
    test = test.reshape(test.shape[0], test.shape[1])
    test_scaled = scaler.transform(test)
    return scaler, train_scaled, test_scaled
 
# inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
    new_row = [x for x in X] + [value]
    array = np.array(new_row)
    array = array.reshape(1, len(array))
    inverted = scaler.inverse_transform(array)
    return inverted[0, -1]
 
# fit an LSTM network to training data
def fit_lstm(train, batch_size, nb_epoch, neurons):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    model = Sequential()
    model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    for i in range(nb_epoch):
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
        model.reset_states()
    return model
 
# make a one-step forecast
def forecast_lstm(model, batch_size, X):
    X = X.reshape(1, 1, len(X))
    yhat = model.predict(X, batch_size=batch_size)
    return yhat[0,0]
 
sale_series = data['UNITS']
# transform data to be stationary
train_raw_values = sale_series.values
diff_values = difference(train_raw_values, 1)
 
# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values, 1)
train = supervised.values

sale_series = test_df['UNITS']
# transform data to be stationary
test_raw_values = sale_series.values
diff_values = difference(test_raw_values, 1)
 
# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values, 1)
test = supervised.values

# %%
# transform the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)
 
# fit the model
lstm_model = fit_lstm(train_scaled, 1, 1, 4)
# forecast the entire training dataset to build up state for forecasting
predictions = list()
for i in range(len(train_scaled)):
    # make one-step forecast
    X, y = train_scaled[i, 0:-1], train_scaled[i, -1]
    yhat = forecast_lstm(lstm_model, 1, X)
    # invert scaling
    yhat = invert_scale(scaler, X, yhat)
    # invert differencing
    yhat = inverse_difference(train_raw_values, yhat, len(train_scaled)+1-i)
    # store forecast
    predictions.append(yhat)
    expected = train_raw_values[i]
rmse = np.sqrt(mean_squared_error(train_raw_values[:-1], predictions))
print('Train RMSE: %.3f' % rmse)
# Out:
# Train RMSE: 3.185

# %%
# cross validation on the test data
predictions = list()
for i in range(len(test_scaled)):
    # make one-step forecast
    X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
    yhat = forecast_lstm(lstm_model, 1, X)
    # invert scaling
    yhat = invert_scale(scaler, X, yhat)
    # invert differencing
    yhat = inverse_difference(test_raw_values, yhat, len(test_scaled)+1-i)
    # store forecast
    predictions.append(yhat)
    expected = test_raw_values[i]
    print('Predicted=%f, Expected=%f' % (yhat, expected))
# Out:
# Predicted=54.915863, Expected=52.330000
# Predicted=38.934894, Expected=30.684000
# Predicted=32.200113, Expected=23.248000
# Predicted=37.778612, Expected=32.950000
# Predicted=26.117752, Expected=17.636000
# Predicted=37.160457, Expected=34.918000
# Predicted=43.957866, Expected=44.626000
# Predicted=39.447869, Expected=38.020000
# Predicted=29.333059, Expected=24.222000
# Predicted=31.176706, Expected=27.978000
# Predicted=26.887248, Expected=22.590000
# Predicted=26.998402, Expected=23.666000
# Predicted=27.165039, Expected=24.548000
# Predicted=30.435017, Expected=29.616000
# Predicted=25.868237, Expected=23.320000
# Predicted=28.659988, Expected=27.786000
# Predicted=24.810182, Expected=22.522000
# Predicted=24.629428, Expected=22.778000
# Predicted=24.787139, Expected=23.368000
# Predicted=31.136729, Expected=32.518000
# Predicted=31.526803, Expected=32.680000
# Predicted=25.067505, Expected=23.402000
# Predicted=20.145685, Expected=16.960000
# Predicted=18.448996, Expected=15.330000
# Predicted=30.810457, Expected=33.262000
# Predicted=20.263881, Expected=17.912000
# Predicted=23.915368, Expected=23.648000
# Predicted=18.293760, Expected=15.810000
# Predicted=23.291482, Expected=23.396000
# Predicted=16.533665, Expected=13.882000
# Predicted=27.814529, Expected=30.278000
# Predicted=11.894893, Expected=7.512000
# Predicted=18.852945, Expected=18.382000
# Predicted=19.384461, Expected=19.140000
# Predicted=18.523816, Expected=17.978000
# Predicted=15.505749, Expected=13.886000
# Predicted=16.980699, Expected=16.332000
# Predicted=27.394378, Expected=30.986000
# Predicted=19.759719, Expected=19.492000
# Predicted=14.557846, Expected=12.382000
# Predicted=12.180254, Expected=9.604000
# Predicted=12.470774, Expected=10.602000
# Predicted=9.792478, Expected=7.260000
# Predicted=10.244897, Expected=8.462000
# Predicted=15.735421, Expected=16.500000
# Predicted=9.942656, Expected=8.190000
# Predicted=11.166963, Expected=10.342000
# Predicted=10.824892, Expected=10.028000
# Predicted=9.132409, Expected=7.840000
# Predicted=11.869988, Expected=11.966000
# Predicted=9.391215, Expected=8.460000
# Predicted=13.866398, Expected=14.950000
# Predicted=7.158397, Expected=5.324000
# Predicted=11.944662, Expected=12.500000
# Predicted=16.091179, Expected=18.142000
# Predicted=12.338621, Expected=12.448000
# Predicted=14.505662, Expected=15.524000
# Predicted=12.349522, Expected=12.310000
# Predicted=15.779313, Expected=17.174000
# Predicted=10.717713, Expected=9.816000
# Predicted=15.358695, Expected=16.590000
# Predicted=13.420518, Expected=13.618000
# Predicted=12.237326, Expected=11.982000
# Predicted=12.442496, Expected=12.376000
# Predicted=15.072076, Expected=16.102000
# Predicted=20.433692, Expected=23.382000
# Predicted=10.123431, Expected=8.380000
# Predicted=17.607902, Expected=19.366000
# Predicted=12.815468, Expected=12.282000
# Predicted=12.456821, Expected=11.986000
# Predicted=15.457588, Expected=16.325000
# Predicted=17.172621, Expected=18.548000
# Predicted=13.588658, Expected=13.276000
# Predicted=20.568682, Expected=23.170000
# Predicted=17.672910, Expected=18.566000
# Predicted=20.561046, Expected=22.490000
# Predicted=16.483030, Expected=16.418000
# Predicted=25.016722, Expected=28.442000
# Predicted=19.975332, Expected=20.678000
# Predicted=22.346221, Expected=23.952000
# Predicted=21.515010, Expected=22.498000
# Predicted=29.597349, Expected=33.640000
# Predicted=18.704827, Expected=17.616000
# Predicted=20.887975, Expected=21.076000
# Predicted=20.065453, Expected=19.932000
# Predicted=17.850765, Expected=16.930000
# Predicted=19.471684, Expected=19.462000
# Predicted=31.570357, Expected=36.342000
# Predicted=26.468071, Expected=28.187000
# Predicted=18.970153, Expected=17.452000
# Predicted=33.258432, Expected=37.820000
# Predicted=33.919272, Expected=37.744000
# Predicted=32.121892, Expected=34.486000
# Predicted=22.470041, Expected=20.608000
# Predicted=22.134093, Expected=20.708000
# Predicted=27.372365, Expected=28.398000
# Predicted=19.154933, Expected=16.724000
# Predicted=31.164191, Expected=34.118000
# Predicted=28.621396, Expected=29.894000
# Predicted=35.138100, Expected=38.780000
# Predicted=36.003498, Expected=39.224000
# Predicted=29.591265, Expected=29.650000
# Predicted=37.388387, Expected=40.660000
# Predicted=33.620790, Expected=34.728000
# Predicted=47.250685, Expected=53.568000
# Predicted=45.731859, Expected=50.132000
# Predicted=38.020854, Expected=38.540000
# Predicted=28.219667, Expected=24.908000
# Predicted=24.263513, Expected=20.264000
# Predicted=29.263798, Expected=28.198000
# Predicted=30.709176, Expected=30.430000
# Predicted=23.915239, Expected=21.024000
# Predicted=20.196137, Expected=16.538000
# Predicted=26.088228, Expected=25.594000
# Predicted=22.822212, Expected=21.084000
# Predicted=24.728953, Expected=24.152000
# Predicted=20.946275, Expected=18.976000
# Predicted=15.692780, Expected=12.106000
# Predicted=16.469431, Expected=14.014000
# Predicted=22.063250, Expected=22.330000
# Predicted=32.625289, Expected=36.916000
# Predicted=18.505924, Expected=16.284000
# Predicted=17.345890, Expected=15.310000
# Predicted=23.638708, Expected=24.564000
# Predicted=19.660670, Expected=18.762000
# Predicted=25.414042, Expected=27.050000
# Predicted=18.990199, Expected=17.700000
# Predicted=29.069584, Expected=32.140000
# Predicted=22.927729, Expected=22.860000
# Predicted=28.089065, Expected=30.186000
# Predicted=21.581988, Expected=20.650000
# Predicted=21.448687, Expected=20.774000
# Predicted=19.030382, Expected=17.578000
# Predicted=21.097689, Expected=20.836000
# Predicted=20.366464, Expected=19.876000
# Predicted=37.922585, Expected=44.404000
# Predicted=29.266111, Expected=30.908000
# Predicted=26.283834, Expected=26.516000
# Predicted=33.299989, Expected=36.360000
# Predicted=27.660772, Expected=27.844000
# Predicted=19.132467, Expected=16.010000
# Predicted=23.315979, Expected=22.672000
# Predicted=32.672411, Expected=35.860000
# Predicted=25.660939, Expected=25.366000
# Predicted=29.125314, Expected=30.380000
# Predicted=32.625491, Expected=35.016000
# Predicted=33.207969, Expected=35.342000
# Predicted=29.677730, Expected=30.010000
# Predicted=22.694007, Expected=20.278000
# Predicted=42.738317, Expected=48.764000
# Predicted=26.310920, Expected=24.610000
# Predicted=26.282161, Expected=25.154000
# Predicted=29.316370, Expected=29.682000
# Predicted=24.431761, Expected=22.794000
# Predicted=18.923542, Expected=15.534000
# Predicted=26.068444, Expected=26.322000
# Predicted=28.153220, Expected=29.124000
# Predicted=21.515127, Expected=19.650000
# Predicted=26.811610, Expected=27.540000
# Predicted=33.710832, Expected=36.980000
# Predicted=29.973273, Expected=31.040000
# Predicted=27.871121, Expected=27.950000
# Predicted=16.388595, Expected=11.986000
# Predicted=21.629104, Expected=20.420000
# Predicted=20.725276, Expected=19.380000
# Predicted=18.077876, Expected=15.990000
# Predicted=27.150193, Expected=29.134000
# Predicted=27.716413, Expected=29.428000
# Predicted=29.793592, Expected=31.976000
# Predicted=34.491738, Expected=38.084000
# Predicted=26.887663, Expected=26.720000
# Predicted=22.399596, Expected=20.612000
# Predicted=34.431638, Expected=37.882000
# Predicted=25.680122, Expected=24.902000
# Predicted=31.084278, Expected=32.758000
# Predicted=25.305705, Expected=24.336000
# Predicted=32.143592, Expected=34.202000
# Predicted=31.174118, Expected=32.400000
# Predicted=31.891749, Expected=33.200000
# Predicted=27.767287, Expected=27.208000
# Predicted=31.945483, Expected=33.262000
# Predicted=21.177265, Expected=17.982000
# Predicted=29.729502, Expected=30.772000
# Predicted=34.191879, Expected=36.736000
# Predicted=29.130670, Expected=29.130000
# Predicted=25.066068, Expected=23.542000
# Predicted=29.890553, Expected=30.694000
# Predicted=33.660876, Expected=35.782000
# Predicted=30.067448, Expected=30.322000
# Predicted=29.829866, Expected=30.016000
# Predicted=41.985023, Expected=46.962000
# Predicted=37.540936, Expected=39.684000
# Predicted=34.715062, Expected=35.380000
# Predicted=44.845539, Expected=49.468000
# Predicted=29.259948, Expected=26.812000
# Predicted=30.487257, Expected=29.280000
# Predicted=23.874911, Expected=20.346000
# Predicted=29.717879, Expected=29.372000
# Predicted=28.669699, Expected=27.950000
# Predicted=26.300510, Expected=24.824000
# Predicted=33.751425, Expected=35.582000
# Predicted=24.480190, Expected=22.224000
# Predicted=23.693934, Expected=21.728000
# Predicted=32.379212, Expected=34.296000
# Predicted=27.860777, Expected=27.522000
# Predicted=27.772589, Expected=27.538000
# Predicted=20.378017, Expected=17.292000
# Predicted=24.519045, Expected=23.844000
# Predicted=22.839123, Expected=21.612000
# Predicted=24.715526, Expected=24.524000
# Predicted=22.566250, Expected=21.554000
# Predicted=18.741528, Expected=16.462000
# Predicted=17.531638, Expected=15.310000
# Predicted=18.619697, Expected=17.322000
# Predicted=22.851526, Expected=23.498000
# Predicted=18.205850, Expected=16.834000
# Predicted=21.409302, Expected=21.662000
# Predicted=24.310077, Expected=25.638000
# Predicted=15.675107, Expected=13.296000
# Predicted=16.938351, Expected=15.688000
# Predicted=15.568929, Expected=14.042000
# Predicted=21.141842, Expected=22.180000
# Predicted=20.349072, Expected=20.808000
# Predicted=25.452307, Expected=27.862000
# Predicted=23.543865, Expected=24.666000
# Predicted=18.930259, Expected=18.036000
# Predicted=16.780212, Expected=15.310000
# Predicted=19.141141, Expected=18.984000
# Predicted=13.802877, Expected=11.568000
# Predicted=27.884028, Expected=31.752000
# Predicted=26.216501, Expected=28.520000
# Predicted=15.403534, Expected=12.998000
# Predicted=21.018989, Expected=21.524000
# Predicted=15.243325, Expected=13.334000
# Predicted=27.577792, Expected=31.038000
# Predicted=11.686386, Expected=8.142000
# Predicted=17.893695, Expected=17.788000
# Predicted=14.792181, Expected=13.436000
# Predicted=20.317195, Expected=21.494000
# Predicted=19.781429, Expected=20.460000
# Predicted=15.641056, Expected=14.560000
# Predicted=15.046194, Expected=14.030000
# Predicted=17.312362, Expected=17.446000
# Predicted=19.844444, Expected=20.956000
# Predicted=23.065880, Expected=25.220000
# Predicted=19.209563, Expected=19.382000
# Predicted=17.018294, Expected=16.362000
# Predicted=27.177221, Expected=30.744000
# Predicted=30.421161, Expected=34.476000
# Predicted=22.697841, Expected=22.868000
# Predicted=24.918639, Expected=26.078000
# Predicted=22.625894, Expected=22.676000
# Predicted=23.363471, Expected=23.782000
# Predicted=29.379352, Expected=32.146000
# Predicted=23.503304, Expected=23.368000
# Predicted=22.025829, Expected=21.446000
# Predicted=15.678779, Expected=12.774000
# Predicted=21.497850, Expected=21.636000
# Predicted=22.576801, Expected=23.092000
# Predicted=24.818422, Expected=26.132000
# Predicted=23.688970, Expected=24.290000
# Predicted=14.780331, Expected=11.782000
# Predicted=22.752144, Expected=23.692000
# Predicted=13.797799, Expected=10.964000
# Predicted=23.466735, Expected=25.190000
# Predicted=25.585498, Expected=27.716000
# Predicted=25.500753, Expected=27.152000
# Predicted=19.839845, Expected=18.936000
# Predicted=28.545145, Expected=31.388000
# Predicted=21.889366, Expected=21.474000
# Predicted=20.719813, Expected=20.042000
# Predicted=17.396651, Expected=15.600000
# Predicted=17.448349, Expected=16.128000
# Predicted=20.593268, Expected=20.832000
# Predicted=18.941332, Expected=18.468000
# Predicted=16.632506, Expected=15.384000

# %%
# report performance
rmse = np.sqrt(mean_squared_error(test_raw_values[:-1], predictions))
print('Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
plt.plot(test_raw_values[:-1])
plt.plot(predictions)
blue_patch = mpatches.Patch(color='blue', label='raw_values')
orange_patch = mpatches.Patch(color='orange', label='predictions')
plt.legend(handles=[blue_patch, orange_patch])
plt.ylabel('Units')
plt.xlabel('day')
plt.title('Forecast of Units Per Day')
plt.show()
# Out:
# Test RMSE: 2.286

# %% [markdown]
# ## Save to csv

# %%
pred_df = pd.DataFrame(predictions)
pred_df.index = test_df['DATENEW'][:-1]
pred_df.columns = ['Bananas']
pred_df
# Out:
#               Bananas
# DATENEW
# 2019-01-02  54.915863
# 2019-01-03  38.934894
# 2019-01-04  32.200113
# 2019-01-05  37.778612
# 2019-01-06  26.117752
# ...               ...
# 2019-10-08  17.396651
# 2019-10-09  17.448349
# 2019-10-10  20.593268
# 2019-10-11  18.941332
# 2019-10-12  16.632506
#
# [276 rows x 1 columns]

# %%
path = os.path.join('predictions', 'Bananas lstm prediction.csv')
pred_df.to_csv(path)

# %% [markdown]
# # Find Elbow Point

# %%
# fit an LSTM network to training data
test_code = '''
def fit_lstm(train, batch_size, nb_epoch, neurons):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    model = Sequential()
    model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    for i in range(nb_epoch):
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
        model.reset_states()
    return model
'''

# %%
batch_size = 1
result = pd.DataFrame(columns = ['time', 'rmse', 'nb_epoch', 'neurons'])
for nb_epoch in range(1, 11):
    for neurons in range(1, 11):
        #training part
        X, y = train_scaled[:, 0:-1], train_scaled[:, -1]
        X = X.reshape(X.shape[0], 1, X.shape[1])
        model = Sequential()
        model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
        model.add(Dense(1))
        model.compile(loss='mean_squared_error', optimizer='adam')
        test_code = '''
model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
model.reset_states()
        '''
        time_cost = timeit.repeat(stmt = test_code, setup = 'from __main__ import ' + ', '.join(globals()), repeat = nb_epoch, number = 1)
        
        #predicting part
        predictions = list()
        for i in range(len(test_scaled)):
            # make one-step forecast
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            yhat = forecast_lstm(model, 1, X)
            # invert scaling
            yhat = invert_scale(scaler, X, yhat)
            # invert differencing
            yhat = inverse_difference(test_raw_values, yhat, len(test_scaled)+1-i)
            # store forecast
            predictions.append(yhat)
            expected = test_raw_values[i]
        rmse = np.sqrt(mean_squared_error(test_raw_values[:-1], predictions))
        
        #append to result
        result = result.append(pd.DataFrame({'time': time_cost, 'rmse': rmse, 'nb_epoch': nb_epoch, 'neurons': neurons}))
result
# Out:
# [15.008795768790876, 10.32486289266497, 4.633399024128915, 16.915323070384563, 8.31143576063216, 13.286923098929226, 5.062467338487506, 9.743047620998697, 5.673615472875537, 8.13163551340066, 8.730200468314813, 7.730070458484815, 3.7828762330971673, 5.863301769137384, 1.48588691173494, 1.8556084716841594, 6.287949935093524, 19.007895818963647, 4.893973820356654, 8.99599944009632, 5.104353921493517, 11.576050964936616, 6.079772654259578, 8.730955715060235, 11.59321960643679, 4.132422470331193, 7.315810814745725, 7.835905621655286, 18.026617791011926, 8.040740494990722, 4.475913176916541, 3.590524237738924, 14.174290039844811, 1.684789600577207, 7.087754764623942, 6.923108961835505, 17.755915729105475, 8.080612604796888, 14.266249108143153, 8.146007848417387, 11.904739152111112, 18.68306132495404, 13.617057216897608, 8.147716845806688, 15.241810134038332, 7.236469293000178, 7.610148195013405, 15.732116420455277, 10.892626917250457, 17.28856046957523, 9.382976809116082, 9.889441259006041, 4.617302224360409, 13.721666020102798, 14.85383212988824, 11.949657605767252, 6.37130781131238, 3.942668008364739, 21.65618366959691, 4.060538370303811, 16.02190572617203, 16.73722682849318, 17.768123530782763, 23.324103297889238, 11.52405599808507, 8.304614829884844, 10.842241677192973, 29.81528875157238, 9.769735119162128, 19.227997557751838, 15.137496345795691, 8.085997490506621, 2.3897667790129793, 3.9748566628